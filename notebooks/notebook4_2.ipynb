# %%
from Lib.myModules.my_ML_Modules_1 import *
import math

# %%
data_dir = "../data"
infantNum = 4
ECG_dataset = f"{data_dir}/infant{infantNum}_ecg"
RESP_dataset = f"{data_dir}/infant{infantNum}_resp"
# Read all the data
signal_ecg_0 = wfdb.rdsamp(f"{data_dir}/infant{infantNum}_ecg")
signal_resp_0 = wfdb.rdsamp(f"{data_dir}/infant{infantNum}_resp")
print(f'ECG DATA: {signal_ecg_0[1]}')
print(F'RESP DATA: {signal_resp_0[1]}')
totalDuration_ECG = num2Time(num=signal_ecg_0[1]['sig_len'], fs=signal_ecg_0[1]['fs'])
print(f'{totalDuration_ECG} sec, {secs2minutes(totalDuration_ECG)} minutes, {secs2hours(totalDuration_ECG)} hours')
totalDuration_RESP = num2Time(num=signal_resp_0[1]['sig_len'], fs=signal_resp_0[1]['fs'])
print(f'{totalDuration_RESP} sec, {secs2minutes(totalDuration_RESP)} minutes, {secs2hours(totalDuration_RESP)} hours')
# Start and end time defined
# start_time_secs = hours2secs(1)
# end_time_secs = hours2secs(1.1)

def training_pipeline(start_time_secs, end_time_secs):
    ECG_startNum = time2Num(start_time_secs, signal_ecg_0[1]['fs'])
    ECG_endNum = time2Num(end_time_secs, signal_ecg_0[1]['fs'])
    print(f'start: {ECG_startNum}, end: {ECG_endNum}')
    RESP_startNum = time2Num(start_time_secs, signal_resp_0[1]['fs'])
    RESP_endNum = time2Num(end_time_secs, signal_resp_0[1]['fs'])
    print(f'start: {RESP_startNum}, end: {RESP_endNum}')
    signal_ECG, signal_ECG_startTime_secs, signal_ECG_endTime_secs = read_Data(ECG_dataset, startNum=ECG_startNum, endNum=ECG_endNum)
    signal_RESP, signal_RESP_startTime_secs, signal_RESP_endTime_secs = read_Data(RESP_dataset, startNum=RESP_startNum, endNum=RESP_endNum)
    # print(signal_ECG[0].shape)
    signal_ECG_1 = iqr_smooth(signal=signal_ECG[0],hiPerc=90,loPerc=10, cutoff_factor=1)
    # print(signal_RESP[0].shape)
    signal_RESP_1 = iqr_smooth(signal=signal_RESP[0],hiPerc=90,loPerc=10, cutoff_factor=1)
    signal_ECG_2 = norm_signal(signal=signal_ECG_1)
    signal_RESP_2 = norm_signal(signal=signal_RESP_1)
    hrs_0 = cal_heartrate(signal=signal_ECG_2, fs=signal_ECG[1]['fs'])
    rrs_0 = cal_resprate(signal=signal_RESP_2, fs=signal_RESP[1]['fs'])
    if (rrs_0.shape[0] < hrs_0.shape[0]):
        hrs_1 = data_resample(data_fixNan(hrs_0), rrs_0.shape[0])
        rrs_1 = data_fixNan(rrs_0)
    else:
        rrs_1 = data_resample(data_fixNan(rrs_0), hrs_0.shape[0])
        hrs_1 = data_fixNan(hrs_0)
    correlationTest(rrs_1[:],hrs_1[:], plot=False)
    print("---------------------------------------------")
    print("--- Linear Regression ---")
    lr_model_1 = train_lr_model(X=rrs_1, y=hrs_1)
    print("---------------------------------------------")
    print("--- Polynomial Regression ---")
    pr_model_1 = train_pr_model(X=rrs_1, y=hrs_1, degree=6)
    print("---------------------------------------------")
    print("--- SVR Radius Basis Function---")
    svr_rbf_1 = train_svr_rbf_model(X=rrs_1, y=hrs_1, param_C=100, param_gamma=0.1, seed=42)
    print("--- SVR Linear ---")
    svr_lin_1 = train_svr_lin_model(X=rrs_1, y=hrs_1, param_C=1000, param_gamma='auto', seed=42)
    print("--- SVR Polynomial ---")
    svr_poly_1 = train_svr_poly_model(X=rrs_1, y=hrs_1, param_C=1000, param_gamma='auto', param_degree=6, seed=42)

for i in np.arange(1, math.floor(secs2hours(totalDuration_ECG)), 0.1):
    print(f"Data bin: {i}")
    start_time_secs = hours2secs(i)
    end_time_secs = hours2secs(i+0.1)
    training_pipeline(start_time_secs=start_time_secs, end_time_secs=end_time_secs)
# Out:
# ECG DATA: {'fs': 500, 'sig_len': 78684614, 'n_sig': 1, 'base_date': None, 'base_time': None, 'units': ['mV'], 'sig_name': ['II'], 'comments': []}
# RESP DATA: {'fs': 50, 'sig_len': 7868296, 'n_sig': 1, 'base_date': None, 'base_time': None, 'units': ['NU'], 'sig_name': ['RESP'], 'comments': []}
# 157369.228 sec, 2622.8204666666666 minutes, 43.71367444444444 hours
# 157365.92 sec, 2622.7653333333337 minutes, 43.71275555555556 hours
# start: 1800000, end: 1980000
# start: 180000, end: 198000
# 90th percentile: 0.16400837520909167, 10th percentile: -0.23755355254763474, IQR: 0.4015619277567264
# Identified outliers: 9621
# Data Shape: (180000,)
# 90th percentile: 24.07121214669968, 10th percentile: 20.537240474173423, IQR: 3.533971672526256
# Identified outliers: 83
# Data Shape: (18000,)
# [[141.78716262  19.45454482]
#  [ 19.45454482 249.79800093]]
# Pearsons correlation: 0.103
# Spearmans correlation: 0.074
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.010454237650825426
# Intercept: [129.89598]
# Coefficients: [[0.13415053]]
# Mean absolute error: 9.79
# Mean squared error: 257.39
# Root mean squared error: 16.04
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.011814241944122506
# Intercept: [131.59723]
# Coefficients: [[ 1.2934562e-09  2.5849705e-08  1.2000611e-06  1.9130819e-05
#   -7.4896809e-07  7.4045428e-09]]
# Mean absolute error: 9.63
# Mean squared error: 248.96
# Root mean squared error: 15.78
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: 0.003105500229571345
# Intercept: [0.19481625]
# Mean absolute error: 10.90
# Mean squared error: 289.05
# Root mean squared error: 17.00
# --- SVR Linear ---
# Coefficient of determination: -0.02035107709947015
# Intercept: [0.59539685]
# Mean absolute error: 11.52
# Mean squared error: 313.09
# Root mean squared error: 17.69
# --- SVR Polynomial ---
# Coefficient of determination: -0.03435868529826136
# Intercept: [0.62306214]
# Mean absolute error: 10.66
# Mean squared error: 291.89
# Root mean squared error: 17.08
# start: 1980000, end: 2160000
# start: 198000, end: 216000
# 90th percentile: 0.09116446297031001, 10th percentile: -0.10957267183931492, IQR: 0.20073713480962493
# Identified outliers: 9023
# Data Shape: (180000,)
# 90th percentile: 23.644734427577905, 10th percentile: 21.484425850357134, IQR: 2.1603085772207713
# Identified outliers: 348
# Data Shape: (18000,)
# [[166.00304233  13.36850361]
#  [ 13.36850361  78.4051975 ]]
# Pearsons correlation: 0.117
# Spearmans correlation: 0.070
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.014638366879798581
# Intercept: [117.552444]
# Coefficients: [[0.08293003]]
# Mean absolute error: 5.51
# Mean squared error: 79.32
# Root mean squared error: 8.91
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.0277186901068609
# Intercept: [117.599335]
# Coefficients: [[ 1.6312064e-09 -8.2508173e-08  1.5160313e-06  2.4349147e-05
#   -9.3639267e-07  9.0602654e-09]]
# Mean absolute error: 5.38
# Mean squared error: 62.50
# Root mean squared error: 7.91
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: 0.043470206956858215
# Intercept: [-0.4642038]
# Mean absolute error: 6.82
# Mean squared error: 91.48
# Root mean squared error: 9.56
# --- SVR Linear ---
# Coefficient of determination: -0.006569132262377986
# Intercept: [0.75474936]
# Mean absolute error: 6.77
# Mean squared error: 99.64
# Root mean squared error: 9.98
# --- SVR Polynomial ---
# Coefficient of determination: -0.0015725432990334465
# Intercept: [0.77419185]
# Mean absolute error: 6.44
# Mean squared error: 96.35
# Root mean squared error: 9.82
# start: 2160000, end: 2340000
# start: 216000, end: 234000
# 90th percentile: 0.0946707884691681, 10th percentile: -0.12017930647335934, IQR: 0.21485009494252744
# Identified outliers: 8459
# Data Shape: (180000,)
# 90th percentile: 23.81155631770901, 10th percentile: 21.00839016387424, IQR: 2.80316615383477
# Identified outliers: 103
# Data Shape: (18000,)
# [[167.98467839  -2.87993881]
#  [ -2.87993881 104.85295889]]
# Pearsons correlation: -0.022
# Spearmans correlation: -0.174
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.0005240684213052571
# Intercept: [120.31141]
# Coefficients: [[-0.01822647]]
# Mean absolute error: 5.96
# Mean squared error: 100.63
# Root mean squared error: 10.03
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.004706637929280277
# Intercept: [120.63905]
# Coefficients: [[-4.0700149e-10 -1.1161409e-08 -3.5851656e-07 -5.6670215e-06
#    2.2010992e-07 -2.2296547e-09]]
# Mean absolute error: 5.89
# Mean squared error: 110.68
# Root mean squared error: 10.52
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.07802645454859203
# Intercept: [-0.79464847]
# Mean absolute error: 7.12
# Mean squared error: 118.40
# Root mean squared error: 10.88
# --- SVR Linear ---
# Coefficient of determination: -0.09948216874916915
# Intercept: [0.71175556]
# Mean absolute error: 6.94
# Mean squared error: 122.64
# Root mean squared error: 11.07
# --- SVR Polynomial ---
# Coefficient of determination: -0.0469364634797087
# Intercept: [0.73416977]
# Mean absolute error: 6.47
# Mean squared error: 119.79
# Root mean squared error: 10.94
# start: 2340000, end: 2520000
# start: 234000, end: 252000
# 90th percentile: 0.10957267183931492, 10th percentile: -0.1402530199543231, IQR: 0.249825691793638
# Identified outliers: 11257
# Data Shape: (180000,)
# 90th percentile: 23.728494372413607, 10th percentile: 21.089358110548748, IQR: 2.6391362618648593
# Identified outliers: 348
# Data Shape: (18000,)
# [[156.21309429   1.86762732]
#  [  1.86762732 190.79293346]]
# Pearsons correlation: 0.011
# Spearmans correlation: -0.081
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 7.956940935760493e-05
# Intercept: [122.85577]
# Coefficients: [[0.0096836]]
# Mean absolute error: 8.37
# Mean squared error: 211.66
# Root mean squared error: 14.55
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.0020390469207675066
# Intercept: [123.18495]
# Coefficients: [[ 4.7195564e-10  9.0793355e-09  4.1338933e-07  6.4913161e-06
#   -2.8904205e-07  3.0810723e-09]]
# Mean absolute error: 8.06
# Mean squared error: 193.99
# Root mean squared error: 13.93
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.016567911990550854
# Intercept: [-0.64378456]
# Mean absolute error: 8.95
# Mean squared error: 203.82
# Root mean squared error: 14.28
# --- SVR Linear ---
# Coefficient of determination: -0.183905257156328
# Intercept: [0.54431894]
# Mean absolute error: 10.28
# Mean squared error: 237.79
# Root mean squared error: 15.42
# --- SVR Polynomial ---
# Coefficient of determination: -0.014532778201797658
# Intercept: [0.60178542]
# Mean absolute error: 8.66
# Mean squared error: 213.74
# Root mean squared error: 14.62
# start: 2520000, end: 2700000
# start: 252000, end: 270000
# 90th percentile: 0.16041439157275705, 10th percentile: -0.2393067152970638, IQR: 0.3997211068698209
# Identified outliers: 8421
# Data Shape: (180000,)
# 90th percentile: 23.72709837333301, 10th percentile: 20.405876960689433, IQR: 3.3212214126435775
# Identified outliers: 183
# Data Shape: (18000,)
# [[147.08822837   5.51194771]
#  [  5.51194771 159.64741524]]
# Pearsons correlation: 0.036
# Spearmans correlation: -0.039
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.001362407724935788
# Intercept: [124.43318]
# Coefficients: [[0.03860885]]
# Mean absolute error: 8.13
# Mean squared error: 149.98
# Root mean squared error: 12.25
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.0005927508372974843
# Intercept: [125.15121]
# Coefficients: [[ 4.1912362e-10  1.9338563e-08  3.6427429e-07  5.6799117e-06
#   -2.2295920e-07  2.1811832e-09]]
# Mean absolute error: 8.23
# Mean squared error: 169.42
# Root mean squared error: 13.02
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.02242259653325296
# Intercept: [-0.64531398]
# Mean absolute error: 8.74
# Mean squared error: 169.62
# Root mean squared error: 13.02
# --- SVR Linear ---
# Coefficient of determination: -0.08830290037863131
# Intercept: [0.57238741]
# Mean absolute error: 9.10
# Mean squared error: 183.99
# Root mean squared error: 13.56
# --- SVR Polynomial ---
# Coefficient of determination: -0.027335639118837962
# Intercept: [0.61016211]
# Mean absolute error: 8.60
# Mean squared error: 175.01
# Root mean squared error: 13.23
# start: 2700000, end: 2880000
# start: 270000, end: 288000
# 90th percentile: 0.09817711396802617, 10th percentile: -0.10518976496574232, IQR: 0.20336687893376848
# Identified outliers: 10771
# Data Shape: (180000,)
# 90th percentile: 22.601923114373438, 10th percentile: 21.651945740028534, IQR: 0.949977374344904
# Identified outliers: 214
# Data Shape: (18000,)
# [[160.34417486  -1.80354444]
#  [ -1.80354444  85.99725249]]
# Pearsons correlation: -0.015
# Spearmans correlation: -0.159
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 4.69258091713165e-05
# Intercept: [120.37764]
# Coefficients: [[-0.00515673]]
# Mean absolute error: 4.24
# Mean squared error: 69.53
# Root mean squared error: 8.34
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.010455394165189591
# Intercept: [119.78283]
# Coefficients: [[ 8.0906842e-10  9.8034064e-08  7.9296007e-07  1.3130414e-05
#   -5.4215730e-07  5.5234395e-09]]
# Mean absolute error: 3.96
# Mean squared error: 58.62
# Root mean squared error: 7.66
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -1.4651035009183757
# Intercept: [-0.24584668]
# Mean absolute error: 11.62
# Mean squared error: 207.57
# Root mean squared error: 14.41
# --- SVR Linear ---
# Coefficient of determination: -0.8510794762904745
# Intercept: [0.51191257]
# Mean absolute error: 9.22
# Mean squared error: 154.49
# Root mean squared error: 12.43
# --- SVR Polynomial ---
# Coefficient of determination: -0.5332464270617006
# Intercept: [0.54720191]
# Mean absolute error: 6.96
# Mean squared error: 124.27
# Root mean squared error: 11.15
# start: 2880000, end: 3060000
# start: 288000, end: 306000
# 90th percentile: 0.09379420709445357, 10th percentile: -0.10781950908988588, IQR: 0.20161371618433946
# Identified outliers: 11646
# Data Shape: (180000,)
# 90th percentile: 22.951620884062486, 10th percentile: 21.350409938620015, IQR: 1.601210945442471
# Identified outliers: 480
# Data Shape: (18000,)
# [[178.94190499   0.72768002]
#  [  0.72768002 131.31637042]]
# Pearsons correlation: 0.005
# Spearmans correlation: -0.202
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 5.895478250028674e-05
# Intercept: [119.16243]
# Coefficients: [[0.00654938]]
# Mean absolute error: 4.94
# Mean squared error: 132.67
# Root mean squared error: 11.52
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.023715348010986737
# Intercept: [118.0893]
# Coefficients: [[ 1.4003469e-09  1.8573385e-07  1.4161706e-06  2.3467028e-05
#   -9.4036483e-07  9.3137515e-09]]
# Mean absolute error: 4.93
# Mean squared error: 134.92
# Root mean squared error: 11.62
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.6691984963871129
# Intercept: [-1.3714568]
# Mean absolute error: 8.89
# Mean squared error: 167.39
# Root mean squared error: 12.94
# --- SVR Linear ---
# Coefficient of determination: -0.6434445754584424
# Intercept: [0.54389011]
# Mean absolute error: 8.31
# Mean squared error: 177.27
# Root mean squared error: 13.31
# --- SVR Polynomial ---
# Coefficient of determination: -0.5510383949628006
# Intercept: [0.60499308]
# Mean absolute error: 7.65
# Mean squared error: 167.52
# Root mean squared error: 12.94
# start: 3060000, end: 3240000
# start: 306000, end: 324000
# 90th percentile: 0.2796294585339317, 10th percentile: -0.40410401374339344, IQR: 0.6837334722773252
# Identified outliers: 6131
# Data Shape: (180000,)
# 90th percentile: 23.55329648779893, 10th percentile: 20.758366728539674, IQR: 2.794929759259258
# Identified outliers: 185
# Data Shape: (18000,)
# [[129.47278673  27.20589245]
#  [ 27.20589245 323.9540117 ]]
# Pearsons correlation: 0.133
# Spearmans correlation: 0.140
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.015356802464111974
# Intercept: [132.5765]
# Coefficients: [[0.1972641]]
# Mean absolute error: 10.45
# Mean squared error: 298.81
# Root mean squared error: 17.29
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.010044117465101032
# Intercept: [134.8628]
# Coefficients: [[ 2.0041449e-09  9.5455604e-08  1.6751077e-06  2.5839687e-05
#   -9.4243921e-07  8.7351353e-09]]
# Mean absolute error: 10.69
# Mean squared error: 326.55
# Root mean squared error: 18.07
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.0037365499972259464
# Intercept: [-0.58016717]
# Mean absolute error: 11.51
# Mean squared error: 324.43
# Root mean squared error: 18.01
# --- SVR Linear ---
# Coefficient of determination: -0.008590621664549047
# Intercept: [0.60811242]
# Mean absolute error: 11.00
# Mean squared error: 329.43
# Root mean squared error: 18.15
# --- SVR Polynomial ---
# Coefficient of determination: -0.04243579134825293
# Intercept: [0.6297958]
# Mean absolute error: 11.47
# Mean squared error: 344.82
# Root mean squared error: 18.57
# start: 3240000, end: 3420000
# start: 324000, end: 342000
# 90th percentile: 0.13324036895660696, 10th percentile: -0.17005678669461677, IQR: 0.3032971556512237
# Identified outliers: 7038
# Data Shape: (180000,)
# 90th percentile: 22.552504746920373, 10th percentile: 21.349013939539418, IQR: 1.2034908073809554
# Identified outliers: 74
# Data Shape: (18000,)
# [[119.90575751   6.6233074 ]
#  [  6.6233074   73.21154046]]
# Pearsons correlation: 0.071
# Spearmans correlation: -0.001
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.00539792153262153
# Intercept: [126.30837]
# Coefficients: [[0.06004358]]
# Mean absolute error: 3.79
# Mean squared error: 51.95
# Root mean squared error: 7.21
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.0009409814778537084
# Intercept: [127.57223]
# Coefficients: [[ 1.8555583e-10 -2.7464970e-09  1.4614031e-07  2.1781129e-06
#   -8.2846157e-08  8.4017060e-10]]
# Mean absolute error: 4.10
# Mean squared error: 88.22
# Root mean squared error: 9.39
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.7822189304829705
# Intercept: [0.25163975]
# Mean absolute error: 8.78
# Mean squared error: 140.48
# Root mean squared error: 11.85
# --- SVR Linear ---
# Coefficient of determination: -0.9630154124976906
# Intercept: [0.71989599]
# Mean absolute error: 9.42
# Mean squared error: 153.45
# Root mean squared error: 12.39
# --- SVR Polynomial ---
# Coefficient of determination: -0.940617420700413
# Intercept: [0.71756238]
# Mean absolute error: 9.34
# Mean squared error: 152.15
# Root mean squared error: 12.33
# start: 3420000, end: 3600000
# start: 342000, end: 360000
# 90th percentile: 0.15778464744861348, 10th percentile: -0.22887539693795972, IQR: 0.3866600443865732
# Identified outliers: 9942
# Data Shape: (180000,)
# 90th percentile: 23.29364065880826, 10th percentile: 21.131238082966597, IQR: 2.1624025758416643
# Identified outliers: 108
# Data Shape: (18000,)
# [[173.99823629  -3.2622849 ]
#  [ -3.2622849  250.43683904]]
# Pearsons correlation: -0.016
# Spearmans correlation: -0.122
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.0004040068564170607
# Intercept: [130.65047]
# Coefficients: [[-0.02373219]]
# Mean absolute error: 10.96
# Mean squared error: 272.70
# Root mean squared error: 16.51
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.013746574388525779
# Intercept: [128.7352]
# Coefficients: [[ 1.6288574e-09  1.3448083e-07  1.4664836e-06  2.3242437e-05
#   -9.0780475e-07  8.6540979e-09]]
# Mean absolute error: 10.67
# Mean squared error: 249.44
# Root mean squared error: 15.79
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: 0.004816133432231751
# Intercept: [-1.0700012]
# Mean absolute error: 11.38
# Mean squared error: 250.77
# Root mean squared error: 15.84
# --- SVR Linear ---
# Coefficient of determination: -0.03556725221803436
# Intercept: [0.5982083]
# Mean absolute error: 10.86
# Mean squared error: 255.64
# Root mean squared error: 15.99
# --- SVR Polynomial ---
# Coefficient of determination: -0.01714536359073482
# Intercept: [0.61883453]
# Mean absolute error: 10.41
# Mean squared error: 254.20
# Root mean squared error: 15.94
# start: 3600000, end: 3780000
# start: 360000, end: 378000
# 90th percentile: 0.10957267183931492, 10th percentile: -0.12096822971060367, IQR: 0.23054090154991858
# Identified outliers: 8395
# Data Shape: (180000,)
# 90th percentile: 23.6461304266585, 10th percentile: 21.31481196206484, IQR: 2.331318464593661
# Identified outliers: 75
# Data Shape: (18000,)
# [[ 86.07821461   2.87257043]
#  [  2.87257043 161.61230474]]
# Pearsons correlation: 0.024
# Spearmans correlation: -0.099
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.0007401123128309983
# Intercept: [124.1802]
# Coefficients: [[0.03740856]]
# Mean absolute error: 7.05
# Mean squared error: 162.89
# Root mean squared error: 12.76
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.0208294154214983
# Intercept: [121.919464]
# Coefficients: [[ 2.9720184e-09  2.3077745e-07  2.6068440e-06  4.0383748e-05
#   -1.6432055e-06  1.6581538e-08]]
# Mean absolute error: 7.34
# Mean squared error: 185.02
# Root mean squared error: 13.60
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.004044935560152174
# Intercept: [-0.81549339]
# Mean absolute error: 8.38
# Mean squared error: 173.33
# Root mean squared error: 13.17
# --- SVR Linear ---
# Coefficient of determination: -0.03372027095826913
# Intercept: [0.57714635]
# Mean absolute error: 7.92
# Mean squared error: 181.65
# Root mean squared error: 13.48
# --- SVR Polynomial ---
# Coefficient of determination: -0.016921501484222112
# Intercept: [0.6081559]
# Mean absolute error: 7.45
# Mean squared error: 178.21
# Root mean squared error: 13.35
# start: 3780000, end: 3960000
# start: 378000, end: 396000
# 90th percentile: 0.0946707884691681, 10th percentile: -0.11483216008760204, IQR: 0.20950294855677015
# Identified outliers: 9343
# Data Shape: (180000,)
# 90th percentile: 23.513510514001975, 10th percentile: 21.437659881157202, IQR: 2.075850632844773
# Identified outliers: 0
# Data Shape: (18000,)
# [[179.24589619   9.94648769]
#  [  9.94648769  77.77341164]]
# Pearsons correlation: 0.084
# Spearmans correlation: -0.008
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.006632193549518939
# Intercept: [120.44463]
# Coefficients: [[0.05345068]]
# Mean absolute error: 4.56
# Mean squared error: 78.92
# Root mean squared error: 8.88
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.0030534240778929966
# Intercept: [121.45276]
# Coefficients: [[ 1.2038343e-10 -1.1024247e-09  9.9078427e-08  1.5044952e-06
#   -2.3358986e-08 -5.9222627e-11]]
# Mean absolute error: 4.49
# Mean squared error: 70.22
# Root mean squared error: 8.38
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.2944168961460778
# Intercept: [-1.15584166]
# Mean absolute error: 6.64
# Mean squared error: 102.32
# Root mean squared error: 10.12
# --- SVR Linear ---
# Coefficient of determination: -0.3370096225193948
# Intercept: [0.63746631]
# Mean absolute error: 6.43
# Mean squared error: 106.11
# Root mean squared error: 10.30
# --- SVR Polynomial ---
# Coefficient of determination: -0.0882904071707098
# Intercept: [0.69910472]
# Mean absolute error: 5.13
# Mean squared error: 93.72
# Root mean squared error: 9.68
# start: 3960000, end: 4140000
# start: 396000, end: 414000
# 90th percentile: 0.08502839334730838, 10th percentile: -0.10518976496574232, IQR: 0.19021815831305072
# Identified outliers: 8918
# Data Shape: (180000,)
# 90th percentile: 23.554692486879528, 10th percentile: 21.487217848518323, IQR: 2.0674746383612046
# Identified outliers: 48
# Data Shape: (18000,)
# [[186.23760579  -1.87248897]
#  [ -1.87248897 109.82206759]]
# Pearsons correlation: -0.013
# Spearmans correlation: -0.067
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 6.290259191299441e-08
# Intercept: [121.3189]
# Coefficients: [[-0.00023737]]
# Mean absolute error: 5.51
# Mean squared error: 91.53
# Root mean squared error: 9.57
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.016059039022392918
# Intercept: [121.649086]
# Coefficients: [[-4.4136800e-10 -2.1564265e-08 -3.9833495e-07 -6.3362709e-06
#    3.1413515e-07 -3.7749768e-09]]
# Mean absolute error: 5.82
# Mean squared error: 111.11
# Root mean squared error: 10.54
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.32293100143256437
# Intercept: [-0.26551952]
# Mean absolute error: 8.49
# Mean squared error: 137.72
# Root mean squared error: 11.74
# --- SVR Linear ---
# Coefficient of determination: -0.3602532424098881
# Intercept: [0.80222399]
# Mean absolute error: 8.60
# Mean squared error: 142.12
# Root mean squared error: 11.92
# --- SVR Polynomial ---
# Coefficient of determination: -0.3481910670986208
# Intercept: [0.79557952]
# Mean absolute error: 8.59
# Mean squared error: 141.19
# Root mean squared error: 11.88
# start: 4140000, end: 4320000
# start: 414000, end: 432000
# 90th percentile: 0.07976890509902126, 10th percentile: -0.0999302767174552, IQR: 0.17969918181647648
# Identified outliers: 9385
# Data Shape: (180000,)
# 90th percentile: 23.46744254434234, 10th percentile: 21.564695797491346, IQR: 1.902746746850994
# Identified outliers: 83
# Data Shape: (18000,)
# [[199.65563821   8.59712947]
#  [  8.59712947  59.76795278]]
# Pearsons correlation: 0.079
# Spearmans correlation: -0.119
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.006814913934116262
# Intercept: [119.26984]
# Coefficients: [[0.04582758]]
# Mean absolute error: 3.33
# Mean squared error: 54.96
# Root mean squared error: 7.41
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.016631772759717056
# Intercept: [119.3497]
# Coefficients: [[ 8.5994123e-10  8.3228770e-08  7.9616945e-07  1.2748503e-05
#   -4.5084619e-07  3.9904933e-09]]
# Mean absolute error: 3.28
# Mean squared error: 70.69
# Root mean squared error: 8.41
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.20925006802381518
# Intercept: [-1.61494952]
# Mean absolute error: 5.57
# Mean squared error: 75.97
# Root mean squared error: 8.72
# --- SVR Linear ---
# Coefficient of determination: -0.3633515872454034
# Intercept: [0.82393293]
# Mean absolute error: 5.76
# Mean squared error: 89.01
# Root mean squared error: 9.43
# --- SVR Polynomial ---
# Coefficient of determination: -0.274745794588499
# Intercept: [0.88036548]
# Mean absolute error: 5.35
# Mean squared error: 88.72
# Root mean squared error: 9.42
# start: 4320000, end: 4500000
# start: 432000, end: 450000
# 90th percentile: 0.08502839334730838, 10th percentile: -0.10343660221631329, IQR: 0.18846499556362167
# Identified outliers: 10318
# Data Shape: (180000,)
# 90th percentile: 23.34975982184819, 10th percentile: 21.478841854034755, IQR: 1.8709179678134333
# Identified outliers: 352
# Data Shape: (18000,)
# [[159.78050998  -2.09422202]
#  [ -2.09422202  99.122412  ]]
# Pearsons correlation: -0.017
# Spearmans correlation: -0.126
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 4.0426063922627264e-05
# Intercept: [123.07893]
# Coefficients: [[-0.00517307]]
# Mean absolute error: 5.24
# Mean squared error: 80.79
# Root mean squared error: 8.99
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.008161510705059105
# Intercept: [124.14582]
# Coefficients: [[-3.9955109e-10 -1.3320956e-08 -3.5417531e-07 -5.6018016e-06
#    1.6272287e-07 -1.0935084e-09]]
# Mean absolute error: 5.48
# Mean squared error: 121.06
# Root mean squared error: 11.00
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.11528954499202837
# Intercept: [-0.4717284]
# Mean absolute error: 6.65
# Mean squared error: 111.11
# Root mean squared error: 10.54
# --- SVR Linear ---
# Coefficient of determination: -0.09046233986239338
# Intercept: [0.57809507]
# Mean absolute error: 6.09
# Mean squared error: 110.77
# Root mean squared error: 10.52
# --- SVR Polynomial ---
# Coefficient of determination: -0.009961819505032388
# Intercept: [0.61114961]
# Mean absolute error: 5.53
# Mean squared error: 105.21
# Root mean squared error: 10.26
# start: 4500000, end: 4680000
# start: 450000, end: 468000
# 90th percentile: 0.113078997338173, 10th percentile: -0.15252515920032636, IQR: 0.26560415653849934
# Identified outliers: 14096
# Data Shape: (180000,)
# 90th percentile: 23.426260571464788, 10th percentile: 21.092010508801877, IQR: 2.3342500626629104
# Identified outliers: 540
# Data Shape: (18000,)
# [[177.58495496   3.21042268]
#  [  3.21042268 153.57805443]]
# Pearsons correlation: 0.019
# Spearmans correlation: -0.141
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 3.971919944323332e-05
# Intercept: [122.52423]
# Coefficients: [[0.00568786]]
# Mean absolute error: 6.96
# Mean squared error: 178.68
# Root mean squared error: 13.37
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.0026452538010499627
# Intercept: [122.13231]
# Coefficients: [[ 4.1985659e-10 -1.2482498e-08  3.8549152e-07  6.1954524e-06
#   -2.2050064e-07  1.9087993e-09]]
# Mean absolute error: 6.56
# Mean squared error: 146.93
# Root mean squared error: 12.12
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.03684561707149547
# Intercept: [-0.90425728]
# Mean absolute error: 7.78
# Mean squared error: 161.43
# Root mean squared error: 12.71
# --- SVR Linear ---
# Coefficient of determination: -0.12713047866589777
# Intercept: [0.64930421]
# Mean absolute error: 9.16
# Mean squared error: 188.27
# Root mean squared error: 13.72
# --- SVR Polynomial ---
# Coefficient of determination: -0.03453648846396917
# Intercept: [0.69069307]
# Mean absolute error: 7.65
# Mean squared error: 171.67
# Root mean squared error: 13.10
# start: 4680000, end: 4860000
# start: 468000, end: 486000
# 90th percentile: 0.15252515920032636, 10th percentile: -0.22002192505334436, IQR: 0.3725470842536707
# Identified outliers: 8784
# Data Shape: (180000,)
# 90th percentile: 24.2786576100761, 10th percentile: 14.227185029975939, IQR: 10.05147258010016
# Identified outliers: 507
# Data Shape: (18000,)
# [[216.35653778 -16.12343725]
#  [-16.12343725 540.24206865]]
# Pearsons correlation: -0.047
# Spearmans correlation: -0.168
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.0017084094317213472
# Intercept: [129.04922]
# Coefficients: [[-0.06646262]]
# Mean absolute error: 8.36
# Mean squared error: 478.81
# Root mean squared error: 21.88
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.005773515327456957
# Intercept: [128.43008]
# Coefficients: [[ 4.2628179e-10  5.4552544e-08  3.8756087e-07  6.2426761e-06
#   -3.0795383e-07  3.3575205e-09]]
# Mean absolute error: 8.37
# Mean squared error: 419.92
# Root mean squared error: 20.49
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.3906003666383937
# Intercept: [-1.20341089]
# Mean absolute error: 15.48
# Mean squared error: 710.21
# Root mean squared error: 26.65
# --- SVR Linear ---
# Coefficient of determination: -0.13267248314910152
# Intercept: [0.28934897]
# Mean absolute error: 11.51
# Mean squared error: 603.73
# Root mean squared error: 24.57
# --- SVR Polynomial ---
# Coefficient of determination: -0.09535706331260463
# Intercept: [0.31276112]
# Mean absolute error: 10.46
# Mean squared error: 586.16
# Root mean squared error: 24.21
# start: 4860000, end: 5040000
# start: 486000, end: 504000
# 90th percentile: 0.20512004168319753, 10th percentile: -0.3199522017707996, IQR: 0.5250722434539972
# Identified outliers: 9017
# Data Shape: (180000,)
# 90th percentile: 25.500994405045084, 10th percentile: 20.45403892896996, IQR: 5.046955476075123
# Identified outliers: 476
# Data Shape: (18000,)
# [[157.84145248   7.42760536]
#  [  7.42760536 267.76283939]]
# Pearsons correlation: 0.036
# Spearmans correlation: -0.060
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.002259174719514312
# Intercept: [127.13931]
# Coefficients: [[0.06264]]
# Mean absolute error: 8.80
# Mean squared error: 248.02
# Root mean squared error: 15.75
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.008993657947785727
# Intercept: [128.53299]
# Coefficients: [[ 7.7997692e-10 -3.7212509e-08  7.3710396e-07  1.1911561e-05
#   -5.3291041e-07  5.7572009e-09]]
# Mean absolute error: 8.65
# Mean squared error: 254.27
# Root mean squared error: 15.95
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: 0.0076887610445217636
# Intercept: [0.07088832]
# Mean absolute error: 9.48
# Mean squared error: 264.56
# Root mean squared error: 16.27
# --- SVR Linear ---
# Coefficient of determination: -0.032482528627976404
# Intercept: [0.57012659]
# Mean absolute error: 9.66
# Mean squared error: 278.98
# Root mean squared error: 16.70
# --- SVR Polynomial ---
# Coefficient of determination: -0.03648725458756186
# Intercept: [0.58442055]
# Mean absolute error: 9.79
# Mean squared error: 280.82
# Root mean squared error: 16.76
# start: 5040000, end: 5220000
# start: 504000, end: 522000
# 90th percentile: 0.18057576319119098, 10th percentile: -0.14200618270375215, IQR: 0.32258194589494316
# Identified outliers: 6530
# Data Shape: (180000,)
# 90th percentile: 22.69056905599122, 10th percentile: 21.694523711986683, IQR: 0.9960453440045356
# Identified outliers: 250
# Data Shape: (18000,)
# [[114.69376728   7.35104368]
#  [  7.35104368  66.04078767]]
# Pearsons correlation: 0.084
# Spearmans correlation: -0.120
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.00699489205887005
# Intercept: [119.61753]
# Coefficients: [[0.06296979]]
# Mean absolute error: 4.22
# Mean squared error: 66.71
# Root mean squared error: 8.17
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.018648018418468082
# Intercept: [121.327675]
# Coefficients: [[ 4.4861162e-10  6.8253816e-09  4.6785610e-07  7.8766307e-06
#   -3.5009393e-07  3.8801962e-09]]
# Mean absolute error: 3.80
# Mean squared error: 46.98
# Root mean squared error: 6.85
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.13687715519235977
# Intercept: [-0.78467699]
# Mean absolute error: 5.18
# Mean squared error: 74.35
# Root mean squared error: 8.62
# --- SVR Linear ---
# Coefficient of determination: -0.3476774160264353
# Intercept: [0.80689264]
# Mean absolute error: 5.59
# Mean squared error: 87.11
# Root mean squared error: 9.33
# --- SVR Polynomial ---
# Coefficient of determination: -0.09271493106455897
# Intercept: [0.85662919]
# Mean absolute error: 6.33
# Mean squared error: 105.43
# Root mean squared error: 10.27
# start: 5220000, end: 5400000
# start: 522000, end: 540000
# 90th percentile: 0.15690806607389898, 10th percentile: -0.13499353170603598, IQR: 0.29190159777993496
# Identified outliers: 6476
# Data Shape: (180000,)
# 90th percentile: 22.513277172755654, 10th percentile: 21.660321734512106, IQR: 0.8529554382435478
# Identified outliers: 178
# Data Shape: (18000,)
# [[189.25962433  21.77757154]
#  [ 21.77757154  74.35412202]]
# Pearsons correlation: 0.184
# Spearmans correlation: 0.122
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.03335786805987351
# Intercept: [114.27979]
# Coefficients: [[0.11097725]]
# Mean absolute error: 4.77
# Mean squared error: 84.60
# Root mean squared error: 9.20
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.024048754061998134
# Intercept: [116.77892]
# Coefficients: [[-1.9100119e-10 -1.3540173e-08 -1.8376379e-07 -2.9946368e-06
#    1.6822872e-07 -1.9546089e-09]]
# Mean absolute error: 4.53
# Mean squared error: 73.42
# Root mean squared error: 8.57
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: 0.028065156336905428
# Intercept: [-0.17135642]
# Mean absolute error: 5.10
# Mean squared error: 80.98
# Root mean squared error: 9.00
# --- SVR Linear ---
# Coefficient of determination: 0.00565646015565735
# Intercept: [0.86426596]
# Mean absolute error: 4.89
# Mean squared error: 84.08
# Root mean squared error: 9.17
# --- SVR Polynomial ---
# Coefficient of determination: -0.0900221900238658
# Intercept: [0.87891895]
# Mean absolute error: 5.23
# Mean squared error: 90.09
# Root mean squared error: 9.49
# start: 5400000, end: 5580000
# start: 540000, end: 558000
# 90th percentile: 0.1446359268278957, 10th percentile: -0.1446359268278957, IQR: 0.2892718536557914
# Identified outliers: 6584
# Data Shape: (180000,)
# 90th percentile: 22.77432900082692, 10th percentile: 21.65054974094794, IQR: 1.1237792598789795
# Identified outliers: 284
# Data Shape: (18000,)
# [[179.06248996   7.62004485]
#  [  7.62004485  59.17187067]]
# Pearsons correlation: 0.074
# Spearmans correlation: -0.018
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.0061717242083302315
# Intercept: [116.60578]
# Coefficients: [[0.04610933]]
# Mean absolute error: 4.18
# Mean squared error: 51.97
# Root mean squared error: 7.21
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.010758896090422465
# Intercept: [117.21561]
# Coefficients: [[ 6.34773401e-10  3.59922154e-08  6.21223421e-07  1.01494325e-05
#   -3.96569988e-07  3.88527255e-09]]
# Mean absolute error: 4.25
# Mean squared error: 64.87
# Root mean squared error: 8.05
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.062354966193837624
# Intercept: [-0.07517418]
# Mean absolute error: 4.97
# Mean squared error: 65.05
# Root mean squared error: 8.07
# --- SVR Linear ---
# Coefficient of determination: -0.16707471089921744
# Intercept: [0.84585352]
# Mean absolute error: 5.16
# Mean squared error: 71.79
# Root mean squared error: 8.47
# --- SVR Polynomial ---
# Coefficient of determination: -0.060403007080740645
# Intercept: [0.86730921]
# Mean absolute error: 4.55
# Mean squared error: 67.04
# Root mean squared error: 8.19
# start: 5580000, end: 5760000
# start: 558000, end: 576000
# 90th percentile: 0.13061062483246338, 10th percentile: -0.13762327583017955, IQR: 0.26823390066264297
# Identified outliers: 7765
# Data Shape: (180000,)
# 90th percentile: 22.95371488268338, 10th percentile: 21.575863790136108, IQR: 1.377851092547271
# Identified outliers: 323
# Data Shape: (18000,)
# [[184.65951566  12.81572933]
#  [ 12.81572933  58.50807675]]
# Pearsons correlation: 0.123
# Spearmans correlation: 0.048
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.013658880137650264
# Intercept: [119.72723]
# Coefficients: [[0.06326424]]
# Mean absolute error: 3.96
# Mean squared error: 69.58
# Root mean squared error: 8.34
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.017121006395957594
# Intercept: [120.36198]
# Coefficients: [[ 8.1936574e-10  5.1741207e-08  8.1222521e-07  1.3445070e-05
#   -5.2584670e-07  5.1720583e-09]]
# Mean absolute error: 3.86
# Mean squared error: 56.95
# Root mean squared error: 7.55
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.09817482676917444
# Intercept: [-0.47933495]
# Mean absolute error: 5.42
# Mean squared error: 73.98
# Root mean squared error: 8.60
# --- SVR Linear ---
# Coefficient of determination: -0.2236144928898791
# Intercept: [0.76750568]
# Mean absolute error: 5.82
# Mean squared error: 82.38
# Root mean squared error: 9.08
# --- SVR Polynomial ---
# Coefficient of determination: -0.009843665691729564
# Intercept: [0.83215953]
# Mean absolute error: 4.52
# Mean squared error: 69.08
# Root mean squared error: 8.31
# start: 5760000, end: 5940000
# start: 576000, end: 594000
# 90th percentile: 0.17969918181647648, 10th percentile: -0.21476243680505724, IQR: 0.3944616186215337
# Identified outliers: 8062
# Data Shape: (180000,)
# 90th percentile: 23.200108720408398, 10th percentile: 21.223374022285867, IQR: 1.9767346981225309
# Identified outliers: 536
# Data Shape: (18000,)
# [[117.14259974  -8.89229719]
#  [ -8.89229719 269.49874699]]
# Pearsons correlation: -0.050
# Spearmans correlation: -0.164
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.0021076578383902866
# Intercept: [127.29585]
# Coefficients: [[-0.06977972]]
# Mean absolute error: 9.82
# Mean squared error: 264.00
# Root mean squared error: 16.25
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.009149692441426382
# Intercept: [125.559555]
# Coefficients: [[ 7.7340806e-10  4.5323372e-09  7.0925006e-07  1.1147958e-05
#   -4.9663993e-07  5.1641420e-09]]
# Mean absolute error: 9.93
# Mean squared error: 286.98
# Root mean squared error: 16.94
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.0075812272004947
# Intercept: [-0.06902086]
# Mean absolute error: 10.69
# Mean squared error: 283.89
# Root mean squared error: 16.85
# --- SVR Linear ---
# Coefficient of determination: -0.028748644504648313
# Intercept: [0.60795673]
# Mean absolute error: 10.75
# Mean squared error: 290.77
# Root mean squared error: 17.05
# --- SVR Polynomial ---
# Coefficient of determination: -0.02503993087399281
# Intercept: [0.60847464]
# Mean absolute error: 10.69
# Mean squared error: 290.00
# Root mean squared error: 17.03
# start: 5940000, end: 6120000
# start: 594000, end: 612000
# 90th percentile: 0.18320550731533455, 10th percentile: -0.2664807379132139, IQR: 0.4496862452285485
# Identified outliers: 10637
# Data Shape: (180000,)
# 90th percentile: 23.597270458837677, 10th percentile: 21.01257816111602, IQR: 2.5846922977216558
# Identified outliers: 634
# Data Shape: (18000,)
# [[166.2105945   17.68471248]
#  [ 17.68471248 229.7955921 ]]
# Pearsons correlation: 0.090
# Spearmans correlation: 0.028
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.008023882816553418
# Intercept: [122.12448]
# Coefficients: [[0.10587101]]
# Mean absolute error: 8.49
# Mean squared error: 218.99
# Root mean squared error: 14.80
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.012354859961556386
# Intercept: [122.09633]
# Coefficients: [[ 1.6921557e-09  2.0010373e-07  1.6568878e-06  2.7158738e-05
#   -9.9437648e-07  9.1410328e-09]]
# Mean absolute error: 8.62
# Mean squared error: 231.23
# Root mean squared error: 15.21
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.10815694427575173
# Intercept: [-1.01114203]
# Mean absolute error: 11.85
# Mean squared error: 275.18
# Root mean squared error: 16.59
# --- SVR Linear ---
# Coefficient of determination: -0.10416175810082029
# Intercept: [0.59474352]
# Mean absolute error: 10.99
# Mean squared error: 284.96
# Root mean squared error: 16.88
# --- SVR Polynomial ---
# Coefficient of determination: -0.13444096264105632
# Intercept: [0.62129738]
# Mean absolute error: 11.30
# Mean squared error: 291.96
# Root mean squared error: 17.09
# start: 6120000, end: 6300000
# start: 612000, end: 630000
# 90th percentile: 0.13324036895660696, 10th percentile: -0.12710429933360531, IQR: 0.2603446682902123
# Identified outliers: 10331
# Data Shape: (180000,)
# 90th percentile: 23.04236082430116, 10th percentile: 21.18079605032772, IQR: 1.8615647739734378
# Identified outliers: 186
# Data Shape: (18000,)
# [[246.5661437   13.14118453]
#  [ 13.14118453  88.49025891]]
# Pearsons correlation: 0.089
# Spearmans correlation: -0.042
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.007137636108215606
# Intercept: [118.06208]
# Coefficients: [[0.05077058]]
# Mean absolute error: 3.60
# Mean squared error: 86.66
# Root mean squared error: 9.31
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.045449385018934585
# Intercept: [118.02677]
# Coefficients: [[ 1.4191935e-09 -7.3579741e-08  1.2723664e-06  2.0624349e-05
#   -8.1411395e-07  8.0214093e-09]]
# Mean absolute error: 3.63
# Mean squared error: 100.46
# Root mean squared error: 10.02
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -2.061583342734875
# Intercept: [-0.20388348]
# Mean absolute error: 20.16
# Mean squared error: 502.92
# Root mean squared error: 22.43
# --- SVR Linear ---
# Coefficient of determination: -1.2855339677021966
# Intercept: [0.43028715]
# Mean absolute error: 12.84
# Mean squared error: 294.35
# Root mean squared error: 17.16
# --- SVR Polynomial ---
# Coefficient of determination: -2.15938255572582
# Intercept: [0.45284517]
# Mean absolute error: 10.22
# Mean squared error: 199.36
# Root mean squared error: 14.12
# start: 6300000, end: 6480000
# start: 630000, end: 648000
# 90th percentile: 0.05084171973344213, 10th percentile: -0.04821197560929857, IQR: 0.0990536953427407
# Identified outliers: 4788
# Data Shape: (180000,)
# 90th percentile: 22.46944280162497, 10th percentile: 0.0, IQR: 22.46944280162497
# Identified outliers: 0
# Data Shape: (18000,)
# [[160.38845379  29.2311372 ]
#  [ 29.2311372   47.12630253]]
# Pearsons correlation: 0.336
# Spearmans correlation: 0.563
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.11463839451438207
# Intercept: [109.23487]
# Coefficients: [[0.18940228]]
# Mean absolute error: 1.34
# Mean squared error: 32.11
# Root mean squared error: 5.67
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.10260847628254688
# Intercept: [111.08148]
# Coefficients: [[ 2.2149729e-09 -2.7616647e-07  2.2025713e-06  3.7509424e-05
#   -1.3020873e-06  1.1474299e-08]]
# Mean absolute error: 1.39
# Mean squared error: 51.49
# Root mean squared error: 7.18
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.7876991480389159
# Intercept: [-1.56278644]
# Mean absolute error: 7.20
# Mean squared error: 82.56
# Root mean squared error: 9.09
# --- SVR Linear ---
# Coefficient of determination: -0.8045992540239812
# Intercept: [0.81189263]
# Mean absolute error: 6.47
# Mean squared error: 82.43
# Root mean squared error: 9.08
# --- SVR Polynomial ---
# Coefficient of determination: -1.1990145824335197
# Intercept: [0.86831148]
# Mean absolute error: 7.14
# Mean squared error: 99.58
# Root mean squared error: 9.98
# start: 6480000, end: 6660000
# start: 648000, end: 666000
# 90th percentile: 0.10606634634045685, 10th percentile: -0.10256002084159876, IQR: 0.20862636718205563
# Identified outliers: 7960
# Data Shape: (180000,)
# 90th percentile: 23.1156507760324, 10th percentile: 0.0, IQR: 23.1156507760324
# Identified outliers: 0
# Data Shape: (18000,)
# [[ 273.32185498 -584.14124736]
#  [-584.14124736 2801.48059966]]
# Pearsons correlation: -0.668
# Spearmans correlation: -0.615
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.4408511258722676
# Intercept: [174.72891]
# Coefficients: [[-2.116727]]
# Mean absolute error: 35.36
# Mean squared error: 1536.42
# Root mean squared error: 39.20
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.9537168630662948
# Intercept: [121.944824]
# Coefficients: [[-5.8073879e-09 -1.6008738e-07 -5.5804326e-06 -9.1209731e-05
#    4.0893392e-06 -4.5376190e-08]]
# Mean absolute error: 4.83
# Mean squared error: 108.90
# Root mean squared error: 10.44
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: 0.8937223459116503
# Intercept: [-12.33928649]
# Mean absolute error: 14.48
# Mean squared error: 343.60
# Root mean squared error: 18.54
# --- SVR Linear ---
# Coefficient of determination: 0.3773989250693013
# Intercept: [1.1842879]
# Mean absolute error: 34.03
# Mean squared error: 1792.98
# Root mean squared error: 42.34
# --- SVR Polynomial ---
# Coefficient of determination: 0.8750403627120357
# Intercept: [0.99858611]
# Mean absolute error: 15.30
# Mean squared error: 393.52
# Root mean squared error: 19.84
# start: 6660000, end: 6840000
# start: 666000, end: 684000
# 90th percentile: 0.10606634634045685, 10th percentile: -0.10781950908988588, IQR: 0.21388585543034272
# Identified outliers: 10860
# Data Shape: (180000,)
# 90th percentile: 23.16520874339352, 10th percentile: 21.176608053085936, IQR: 1.9886006903075852
# Identified outliers: 62
# Data Shape: (18000,)
# [[159.90435876   2.20581333]
#  [  2.20581333  56.93807797]]
# Pearsons correlation: 0.023
# Spearmans correlation: -0.294
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 6.7852293818782e-05
# Intercept: [121.36455]
# Coefficients: [[0.00470139]]
# Mean absolute error: 2.69
# Mean squared error: 71.75
# Root mean squared error: 8.47
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.006110130413852777
# Intercept: [121.366356]
# Coefficients: [[ 4.5480114e-10 -1.3579773e-08  4.3218560e-07  6.9840971e-06
#   -2.9243373e-07  3.0037333e-09]]
# Mean absolute error: 2.64
# Mean squared error: 58.68
# Root mean squared error: 7.66
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.6965787096814589
# Intercept: [-2.0951146]
# Mean absolute error: 6.82
# Mean squared error: 84.30
# Root mean squared error: 9.18
# --- SVR Linear ---
# Coefficient of determination: -0.4917161451082752
# Intercept: [0.81406391]
# Mean absolute error: 5.46
# Mean squared error: 86.62
# Root mean squared error: 9.31
# --- SVR Polynomial ---
# Coefficient of determination: -0.26945442262186314
# Intercept: [0.8719669]
# Mean absolute error: 4.92
# Mean squared error: 86.10
# Root mean squared error: 9.28
# start: 6840000, end: 7020000
# start: 684000, end: 702000
# 90th percentile: 0.10168343946688425, 10th percentile: -0.10518976496574232, IQR: 0.20687320443262658
# Identified outliers: 11042
# Data Shape: (180000,)
# 90th percentile: 23.54910849055715, 10th percentile: 21.235658814195105, IQR: 2.313449676362044
# Identified outliers: 29
# Data Shape: (18000,)
# [[176.67765422   7.69766294]
#  [  7.69766294  59.00443532]]
# Pearsons correlation: 0.075
# Spearmans correlation: -0.158
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.004783426799181312
# Intercept: [122.47785]
# Coefficients: [[0.03848851]]
# Mean absolute error: 3.66
# Mean squared error: 70.80
# Root mean squared error: 8.41
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.020868308455510687
# Intercept: [121.953285]
# Coefficients: [[ 1.3446034e-09  9.9327963e-08  1.2825676e-06  2.0896085e-05
#   -8.0858223e-07  7.8432976e-09]]
# Mean absolute error: 3.56
# ...
#  [-1.66717364e-01  9.32041955e+01]]
# Pearsons correlation: -0.001
# Spearmans correlation: -0.119
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 3.4478321573327975e-06
# Intercept: [120.08204]
# Coefficients: [[-0.00118948]]
# Mean absolute error: 5.58
# Mean squared error: 91.14
# Root mean squared error: 9.55
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.0005960542474295893
# Intercept: [120.38626]
# Coefficients: [[-2.5185540e-10 -1.4464768e-08 -2.2432151e-07 -3.5912997e-06
#    1.3445603e-07 -1.2596004e-09]]
# Mean absolute error: 5.75
# Mean squared error: 92.45
# Root mean squared error: 9.61
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.1450743143660953
# Intercept: [0.55207524]
# Mean absolute error: 6.47
# Mean squared error: 106.88
# Root mean squared error: 10.34
# --- SVR Linear ---
# Coefficient of determination: -0.1768849299623212
# Intercept: [0.83582468]
# Mean absolute error: 6.49
# Mean squared error: 109.37
# Root mean squared error: 10.46
# --- SVR Polynomial ---
# Coefficient of determination: -0.21967849166641407
# Intercept: [0.8401828]
# Mean absolute error: 6.88
# Mean squared error: 113.95
# Root mean squared error: 10.67
# start: 36360000, end: 36540000
# start: 3636000, end: 3654000
# 90th percentile: 0.10606634634045685, 10th percentile: -0.10343660221631329, IQR: 0.20950294855677015
# Identified outliers: 10042
# Data Shape: (180000,)
# 90th percentile: 22.64868908357337, 10th percentile: 21.266649993784313, IQR: 1.3820390897890569
# Identified outliers: 498
# Data Shape: (18000,)
# [[187.8650931    7.03772042]
#  [  7.03772042  66.21103915]]
# Pearsons correlation: 0.063
# Spearmans correlation: -0.042
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.00626080626318859
# Intercept: [119.8627]
# Coefficients: [[0.04830777]]
# Mean absolute error: 3.60
# Mean squared error: 54.75
# Root mean squared error: 7.40
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.03315700920075215
# Intercept: [118.61752]
# Coefficients: [[ 1.7343923e-09  5.5878779e-08  1.7012735e-06  2.8074328e-05
#   -1.0484938e-06  9.8232391e-09]]
# Mean absolute error: 3.47
# Mean squared error: 49.00
# Root mean squared error: 7.00
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.6587657971086514
# Intercept: [-0.41561741]
# Mean absolute error: 9.05
# Mean squared error: 130.47
# Root mean squared error: 11.42
# --- SVR Linear ---
# Coefficient of determination: -0.6364553866007392
# Intercept: [0.85613379]
# Mean absolute error: 8.22
# Mean squared error: 131.68
# Root mean squared error: 11.48
# --- SVR Polynomial ---
# Coefficient of determination: -0.5152787716475169
# Intercept: [0.87505617]
# Mean absolute error: 7.48
# Mean squared error: 123.76
# Root mean squared error: 11.12
# start: 36540000, end: 36720000
# start: 3654000, end: 3672000
# 90th percentile: 0.10606634634045685, 10th percentile: -0.10343660221631329, IQR: 0.20950294855677015
# Identified outliers: 10181
# Data Shape: (180000,)
# 90th percentile: 22.77712099898811, 10th percentile: 21.184984047569507, IQR: 1.5921369514186026
# Identified outliers: 135
# Data Shape: (18000,)
# [[128.98247676   9.5477609 ]
#  [  9.5477609   49.36679733]]
# Pearsons correlation: 0.120
# Spearmans correlation: -0.039
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.015275659278556897
# Intercept: [119.560715]
# Coefficients: [[0.076471]]
# Mean absolute error: 3.20
# Mean squared error: 47.75
# Root mean squared error: 6.91
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.0174940894250305
# Intercept: [119.90995]
# Coefficients: [[ 1.1101312e-09  1.3994681e-07  1.0628110e-06  1.7650540e-05
#   -6.4710594e-07  5.9908416e-09]]
# Mean absolute error: 3.07
# Mean squared error: 42.29
# Root mean squared error: 6.50
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.17830632109536948
# Intercept: [-0.53205659]
# Mean absolute error: 4.72
# Mean squared error: 60.65
# Root mean squared error: 7.79
# --- SVR Linear ---
# Coefficient of determination: -0.4643893873765217
# Intercept: [0.79998707]
# Mean absolute error: 5.59
# Mean squared error: 74.45
# Root mean squared error: 8.63
# --- SVR Polynomial ---
# Coefficient of determination: -0.10423309695572525
# Intercept: [0.87583924]
# Mean absolute error: 3.65
# Mean squared error: 62.41
# Root mean squared error: 7.90
# start: 36720000, end: 36900000
# start: 3672000, end: 3690000
# 90th percentile: 0.10168343946688425, 10th percentile: -0.0999302767174552, IQR: 0.20161371618433946
# Identified outliers: 9651
# Data Shape: (180000,)
# 90th percentile: 22.6954550527733, 10th percentile: 21.39926990644084, IQR: 1.296185146332462
# Identified outliers: 137
# Data Shape: (18000,)
# [[194.15372969  -8.73859152]
#  [ -8.73859152  68.58753167]]
# Pearsons correlation: -0.076
# Spearmans correlation: -0.283
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.00517750933266381
# Intercept: [125.766594]
# Coefficients: [[-0.04260588]]
# Mean absolute error: 4.19
# Mean squared error: 69.80
# Root mean squared error: 8.35
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.024913291320864506
# Intercept: [125.84462]
# Coefficients: [[-9.0486584e-11  1.3211451e-09 -8.8282633e-08 -1.4447143e-06
#   -2.1531051e-08  8.0987006e-10]]
# Mean absolute error: 3.90
# Mean squared error: 58.24
# Root mean squared error: 7.63
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.019296468495272556
# Intercept: [0.00137907]
# Mean absolute error: 5.01
# Mean squared error: 80.49
# Root mean squared error: 8.97
# --- SVR Linear ---
# Coefficient of determination: -0.07610515113964778
# Intercept: [0.87598244]
# Mean absolute error: 4.83
# Mean squared error: 86.33
# Root mean squared error: 9.29
# --- SVR Polynomial ---
# Coefficient of determination: -0.07341704078349043
# Intercept: [0.87308072]
# Mean absolute error: 4.83
# Mean squared error: 86.06
# Root mean squared error: 9.28
# start: 36900000, end: 37080000
# start: 3690000, end: 3708000
# 90th percentile: 0.10518976496574232, 10th percentile: -0.12535113658417626, IQR: 0.23054090154991858
# Identified outliers: 11031
# Data Shape: (180000,)
# 90th percentile: 23.3390106289276, 10th percentile: 21.437659881157202, IQR: 1.9013507477703975
# Identified outliers: 200
# Data Shape: (18000,)
# [[169.11477746   4.9835162 ]
#  [  4.9835162   86.26472899]]
# Pearsons correlation: 0.041
# Spearmans correlation: -0.052
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.001813182654434864
# Intercept: [128.25682]
# Coefficients: [[0.03066427]]
# Mean absolute error: 4.78
# Mean squared error: 81.79
# Root mean squared error: 9.04
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.0011346910363284612
# Intercept: [128.85982]
# Coefficients: [[ 3.7874867e-10 -2.6433735e-08  3.3714949e-07  5.3025392e-06
#   -2.0811981e-07  2.0253967e-09]]
# Mean absolute error: 4.79
# Mean squared error: 95.54
# Root mean squared error: 9.77
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.11655785961923404
# Intercept: [-0.59547709]
# Mean absolute error: 5.64
# Mean squared error: 99.99
# Root mean squared error: 10.00
# --- SVR Linear ---
# Coefficient of determination: -0.06294309210727023
# Intercept: [0.68447637]
# Mean absolute error: 5.27
# Mean squared error: 104.42
# Root mean squared error: 10.22
# --- SVR Polynomial ---
# Coefficient of determination: -0.06381752338097346
# Intercept: [0.70446991]
# Mean absolute error: 4.88
# Mean squared error: 101.83
# Root mean squared error: 10.09
# start: 37080000, end: 37260000
# start: 3708000, end: 3726000
# 90th percentile: 0.11483216008760204, 10th percentile: -0.1314872062071779, IQR: 0.24631936629477996
# Identified outliers: 10889
# Data Shape: (180000,)
# 90th percentile: 23.902994257487983, 10th percentile: 21.310623964823055, IQR: 2.5923702926649277
# Identified outliers: 226
# Data Shape: (18000,)
# [[150.9922772    7.50803856]
#  [  7.50803856  87.05112803]]
# Pearsons correlation: 0.065
# Spearmans correlation: -0.038
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.0032320146671386274
# Intercept: [132.66495]
# Coefficients: [[0.04213461]]
# Mean absolute error: 5.19
# Mean squared error: 100.01
# Root mean squared error: 10.00
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.001599116854309024
# Intercept: [133.86493]
# Coefficients: [[-7.7100819e-11 -6.1139729e-09 -6.8624651e-08 -1.0775453e-06
#    3.9477332e-08 -3.1133673e-10]]
# Mean absolute error: 5.19
# Mean squared error: 97.52
# Root mean squared error: 9.88
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: 0.021724446888344406
# Intercept: [0.1252162]
# Mean absolute error: 5.36
# Mean squared error: 93.89
# Root mean squared error: 9.69
# --- SVR Linear ---
# Coefficient of determination: -0.03793816450721077
# Intercept: [0.82127684]
# Mean absolute error: 5.59
# Mean squared error: 99.54
# Root mean squared error: 9.98
# --- SVR Polynomial ---
# Coefficient of determination: -0.026525485040343577
# Intercept: [0.84619467]
# Mean absolute error: 5.37
# Mean squared error: 98.56
# Root mean squared error: 9.93
# start: 37260000, end: 37440000
# start: 3726000, end: 3744000
# 90th percentile: 0.10957267183931492, 10th percentile: -0.12009164833588916, IQR: 0.22966432017520408
# Identified outliers: 11462
# Data Shape: (180000,)
# 90th percentile: 23.810160318628412, 10th percentile: 21.44324387747958, IQR: 2.366916441148831
# Identified outliers: 166
# Data Shape: (18000,)
# [[182.7275588   -7.94737416]
#  [ -7.94737416 164.55371895]]
# Pearsons correlation: -0.046
# Spearmans correlation: -0.076
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.0019254861297018921
# Intercept: [130.35696]
# Coefficients: [[-0.04123238]]
# Mean absolute error: 8.05
# Mean squared error: 170.95
# Root mean squared error: 13.07
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.006607329063163969
# Intercept: [129.34204]
# Coefficients: [[ 3.8310743e-10  1.8320165e-08  3.6977951e-07  6.0111283e-06
#   -2.5974163e-07  2.6426292e-09]]
# Mean absolute error: 7.80
# Mean squared error: 148.60
# Root mean squared error: 12.19
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.03922495721371688
# Intercept: [-0.06085315]
# Mean absolute error: 8.79
# Mean squared error: 176.89
# Root mean squared error: 13.30
# --- SVR Linear ---
# Coefficient of determination: -0.0523866117011027
# Intercept: [0.85296107]
# Mean absolute error: 8.40
# Mean squared error: 180.92
# Root mean squared error: 13.45
# --- SVR Polynomial ---
# Coefficient of determination: -0.05187772178829886
# Intercept: [0.81965128]
# Mean absolute error: 8.71
# Mean squared error: 180.61
# Root mean squared error: 13.44
# start: 37440000, end: 37620000
# start: 3744000, end: 3762000
# 90th percentile: 0.10957267183931492, 10th percentile: -0.12710429933360531, IQR: 0.23667697117292025
# Identified outliers: 11233
# Data Shape: (180000,)
# 90th percentile: 23.68312440229427, 10th percentile: 21.31467236215678, IQR: 2.3684520401374876
# Identified outliers: 166
# Data Shape: (18000,)
# [[ 1.67057528e+02 -3.93079331e-02]
#  [-3.93079331e-02  7.87994625e+01]]
# Pearsons correlation: -0.000
# Spearmans correlation: -0.107
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 4.562367474891804e-05
# Intercept: [129.749]
# Coefficients: [[-0.00459787]]
# Mean absolute error: 4.78
# Mean squared error: 83.92
# Root mean squared error: 9.16
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.015436158299527047
# Intercept: [128.60452]
# Coefficients: [[ 8.4959129e-10  6.1969767e-09  7.6841087e-07  1.2176223e-05
#   -4.4969931e-07  4.0695651e-09]]
# Mean absolute error: 4.77
# Mean squared error: 64.88
# Root mean squared error: 8.05
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: -0.09935686585296133
# Intercept: [-0.56068182]
# Mean absolute error: 7.14
# Mean squared error: 108.99
# Root mean squared error: 10.44
# --- SVR Linear ---
# Coefficient of determination: -0.2196746157681022
# Intercept: [0.72198579]
# Mean absolute error: 6.89
# Mean squared error: 114.62
# Root mean squared error: 10.71
# --- SVR Polynomial ---
# Coefficient of determination: -0.1287611382254943
# Intercept: [0.76823699]
# Mean absolute error: 6.91
# Mean squared error: 114.43
# Root mean squared error: 10.70
# start: 37620000, end: 37800000
# start: 3762000, end: 3780000
# 90th percentile: 0.1770694376923329, 10th percentile: -0.17794601906704743, IQR: 0.35501545675938034
# Identified outliers: 11651
# Data Shape: (180000,)
# 90th percentile: 23.859718285989537, 10th percentile: 21.353201936781204, IQR: 2.506516349208333
# Identified outliers: 518
# Data Shape: (18000,)
# [[172.99233315  -6.67217697]
#  [ -6.67217697 269.51445765]]
# Pearsons correlation: -0.031
# Spearmans correlation: -0.162
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.0005367959991753324
# Intercept: [127.90003]
# Coefficients: [[-0.02897852]]
# Mean absolute error: 10.04
# Mean squared error: 270.89
# Root mean squared error: 16.46
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.011377070378083776
# Intercept: [126.37084]
# Coefficients: [[ 6.3084471e-10  5.0584472e-08  6.3522515e-07  1.0484053e-05
#   -3.6921338e-07  3.1245229e-09]]
# Mean absolute error: 10.02
# Mean squared error: 273.53
# Root mean squared error: 16.54
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: 0.025958053397018732
# Intercept: [-0.34196189]
# Mean absolute error: 11.64
# Mean squared error: 288.21
# Root mean squared error: 16.98
# --- SVR Linear ---
# Coefficient of determination: -0.006690486650587024
# Intercept: [0.67246125]
# Mean absolute error: 11.96
# Mean squared error: 308.59
# Root mean squared error: 17.57
# --- SVR Polynomial ---
# Coefficient of determination: -0.006943333779533489
# Intercept: [0.68062101]
# Mean absolute error: 12.05
# Mean squared error: 310.85
# Root mean squared error: 17.63
# start: 37800000, end: 37980000
# start: 3780000, end: 3798000
# 90th percentile: 0.24018329667177832, 10th percentile: -0.2989142487776511, IQR: 0.5390975454494294
# Identified outliers: 7481
# Data Shape: (180000,)
# 90th percentile: 24.240826034991972, 10th percentile: 20.833890278799863, IQR: 3.4069357561921088
# Identified outliers: 215
# Data Shape: (18000,)
# [[168.29276207   4.28722367]
#  [  4.28722367 228.57874708]]
# Pearsons correlation: 0.022
# Spearmans correlation: -0.041
# ---------------------------------------------
# --- Linear Regression ---
# Coefficient of determination: 0.0012198074360180167
# Intercept: [134.24962]
# Coefficients: [[0.04084711]]
# Mean absolute error: 10.45
# Mean squared error: 219.05
# Root mean squared error: 14.80
# ---------------------------------------------
# --- Polynomial Regression ---
# Coefficient of determination: 0.0038741821980089464
# Intercept: [135.026]
# Coefficients: [[ 7.3513323e-10 -5.2150121e-08  6.9174456e-07  1.1146514e-05
#   -4.3351875e-07  4.1157122e-09]]
# Mean absolute error: 10.51
# Mean squared error: 251.19
# Root mean squared error: 15.85
# ---------------------------------------------
# --- SVR Radius Basis Function---
# Coefficient of determination: 0.006375045798080903
# Intercept: [-0.74025194]
# Mean absolute error: 10.73
# Mean squared error: 250.14
# Root mean squared error: 15.82
# --- SVR Linear ---
